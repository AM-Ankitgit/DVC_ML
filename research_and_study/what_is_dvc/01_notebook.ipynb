# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%capture
# !pip install kagglehub
import kagglehub

# Download latest version
# path = kagglehub.dataset_download("adityakadiwal/water-potability")

# print("Path to dataset files:", path)

# %% [markdown]
# # dvc command
#
# ![image.png](attachment:image.png)

# %% [markdown]
# pip install dvc

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# dvc stage add -n pre_processing \
#   -d src/data_prep.py \
#   -d data/raw/ \
#   -o data/processed \
#   python src/data_prep.py

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# this will create the dvc yaml file and will create stages of cmd, dep and output
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
